# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, plot_roc_curve

# %%
x = np.arange(-10., 10., 0.2) 
y = 2 + 5 * x
plt.plot(x,y)

# %%
#Logistic regressions is an algorithm used for classification problems
def sigmoid(x):
     s = 1 / (1 + np.exp(-(2 + 5 * x)))
     return s 
plt.plot(x, sigmoid(x))

# %%
# df = pd.read_csv('data/breast_cancer.csv')
# df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    int64
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# plt.scatter(df['concave points_worst'], df['diagnosis'])
# plt.ylabel('malignant (1) or benign (0)', fontsize = 12)
# plt.xlabel('concave points_worst', fontsize = 12)
# Out:
# Text(0.5, 0, 'concave points_worst')

# %%
# X = df[['concave points_worst']]
# y = df['diagnosis']

# %%
# this is NOT HOW WE WANT TO DO IT. This is just an example showing the limits of lin reg
# lr = LinearRegression()
# lr.fit(X,y)
# predictions = lr.predict(X)
# plt.scatter(df['concave points_worst'], df['diagnosis'])
# plt.plot(df['concave points_worst'], predictions, color='red')
# plt.ylabel('malignant (1) or benign (0)', fontsize = 12)
# plt.xlabel('concave points_worst', fontsize = 12)
# Out:
# Text(0.5, 0, 'concave points_worst')

# %%
# logreg = LogisticRegression(C = 1000)
# X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=3)
# scaler = StandardScaler()
# scaler.fit(X_train)
# X_train = scaler.transform(X_train)
# X_test = scaler.transform(X_test)
# logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1000)

# %%
# example_df = pd.DataFrame(data = {'worst_concave_points': X_test.flatten(),
#                      'diagnosis': y_test})
# example_df['logistic_preds'] = pd.DataFrame(logreg.predict_proba(X_test)).loc[:, 1].values
# example_df = example_df.sort_values(['logistic_preds'])

# %%
# plt.scatter(example_df['worst_concave_points'], example_df['diagnosis'])
# plt.plot(example_df['worst_concave_points'], example_df['logistic_preds'].values, color='red')
# plt.ylabel('malignant (1) or benign (0)', fontsize = 12)
# plt.xlabel('concave points_worst', fontsize = 12)
# Out:
# Text(0.5, 0, 'concave points_worst')

# %%
df = pd.read_csv('data/breast_cancer.csv')
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
X = df[['concave points_worst']]
y = df['diagnosis']

# %%
logreg = LogisticRegression(C=100)
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=3)
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=100)

# %%
example_df = pd.DataFrame(data={'worst_concave_points': X_test.flatten(), 'diagnosis': y_test})
example_df['logistic_preds'] = pd.DataFrame(logreg.predict_proba(X_test)).loc[:,1].values
example_df = example_df.sort_values(['logistic_preds'])

# %%
plt.scatter(example_df['worst_concave_points'], example_df['diagnosis'])
plt.plot(example_df['worst_concave_points'], example_df['logistic_preds'].values, color='red')
plt.ylabel('malignant (1) or benign (0)', fontsize = 12)
plt.xlabel('concave points_worst', fontsize = 12)
# Out:
# Text(0.5, 0, 'concave points_worst')

# %%
logodds = logreg.intercept_ + logreg.coef_[0] * .6
logodds
# Out:
# array([1.24658836])

# %%
prob = np.exp(logodds)/(1 + np.exp(logodds))
prob
# Out:
# array([0.77670873])

# %%
logreg.predict_proba(np.array([.6]).reshape(-1,1))
# Out:
# array([[0.22329127, 0.77670873]])

# %%
col_names = ['Class label', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols',
'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins','Color intensity', 'Hue', 'OD280/OD315 of diluted wines','Proline']
wine = pd.read_csv('data/wine.csv', header=None, names=col_names)

# %%
wine.head()
# Out:
#    Class label  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0            1    14.23        1.71  2.43               15.6        127
# 1            1    13.20        1.78  2.14               11.2        100
# 2            1    13.16        2.36  2.67               18.6        101
# 3            1    14.37        1.95  2.50               16.8        113
# 4            1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# ...

# %%
print('Class labels', np.unique(wine['Class label']))
# Out:
# Class labels [1 2 3]

# %%
wine['Class label'].value_counts(dropna=False)
# Out:
# 2    71
# 1    59
# 3    48
# Name: Class label, dtype: int64

# %%
X = wine.loc[:, wine.columns[(wine.columns != 'Class label')]]
y = wine.loc[:, 'Class label'].values
print(X.shape, y.shape)
# Out:
# (178, 13) (178,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=3, stratify=y)

# %%
unique, counts = np.unique(y_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# {1: 41, 2: 50, 3: 33}

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
log_reg = LogisticRegression(penalty='l1', C=1.0, solver='liblinear', multi_class='ovr')
log_reg.fit(X_train, y_train)
print('training accuracy:', log_reg.score(X_train, y_train))
print('testing accuracy', log_reg.score(X_test, y_test))
# Out:
# training accuracy: 1.0
# testing accuracy 1.0

# %%
log_reg.intercept_ #the first intercept belongs to the model that fits class 1 versus classes 2 and 3, the second value is the intercept of the model that fits class 2 versus classes 1 and 3, and the third value is the intercept of the model that fits class 3 versus 1 and 2.
# Out:
# array([-1.48286344, -1.08153316, -2.20498186])

# %%
log_reg.coef_ #The weight array that is accessed by log_reg.coef_ attribute that contains three rows of weight coefficients, one weight vector for each class. Each row consists of 13 weights, where each weight is multiplied by the respective feature in the 13-dimensional wine dataset to calculated the net input.
# Out:
# array([[ 0.97737426,  0.        ,  0.96130014, -1.13116998,  0.        ,
#          0.        ,  0.92770496,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.63844004,  2.52038111],
#        [-1.04686234, -0.35267676, -1.18224961,  0.3362812 , -0.05436689,
#          0.        ,  0.05546388,  0.10224366,  0.28509038, -2.30026804,
#          1.64309593,  0.        , -2.0973355 ],
#        [ 0.        ,  0.17324725,  0.41158834,  0.        ,  0.        ,
#          0.        , -2.14336206, -0.11800086,  0.        ,  1.70300773,
#         -0.93108227, -0.69011469,  0.        ]])

# %%
log_reg.predict_proba(X_test[0:1])
# Out:
# array([[0.00313331, 0.91217613, 0.08469056]])

# %%
log_reg.predict(X_test[0:1])
# Out:
# array([2], dtype=int64)

# %%
df = pd.read_csv('data/petal.csv')
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                7.0               3.2                4.7               1.4
# 1                6.4               3.2                4.5               1.5
# 2                6.9               3.1                4.9               1.5
# 3                5.5               2.3                4.0               1.3
# 4                6.5               2.8                4.6               1.5
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
X = df.drop(columns= 'target')
y = df['target']

# %%
logreg = LogisticRegression(C = .001)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=3)
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.001)

# %%
print(f'Training AUC: {roc_auc_score(y_train, logreg.predict_proba(X_train)[:,1])}')
print(f'Testing AUC: {roc_auc_score(y_test, logreg.predict_proba(X_test)[:,1])}')
# Out:
# Training AUC: 0.9565527065527065
# Testing AUC: 0.987012987012987

# %%
plot_roc_curve(logreg, X_train, y_train)
plt.plot([0,1],[0,1], ls = '--', label = "Baseline (AUC = 0.5")
plt.legend()
